# %%
#Variables and data types
age = 19

# %%
#Integer data type
AGE = 18

# %%
#AGE vs age (Python is case-sensitive)
AGE
# Out:
# 18

# %%
#Float data type
pi = 3.14

# %%
temp = 72.5

# %%
#String
name = "Felix"

# %%
#Bool
var = True

# %%
#Conditional Statements -

# %%
age = 7
#if-else statement
if age >= 18:
  print("Person is adult")
else:
  print("Person is not adult")
# Out:
# Person is not adult

# %%
#if-elif-else statement
grade = 85
if grade>= 90:
  print("A")
elif grade >= 80:
  print("B")
else:
  print("C")
# Out:
# B

# %%
#LOOPS

# %%
for i in range(50, 55):
  print(i)
# Out:
# 50
# 51
# 52
# 53
# 54

# %%
for j in range(100, 108):
  print(j)
# Out:
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107

# %%
#Dataframe and Pandas
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/course-catalog.csv")
df
# Out:
#        Year    Term YearTerm Subject  Number                          Name  \
# 0      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 1      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 2      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 3      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 4      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                           ...
# 11816  2023  Spring  2023-sp    WRIT     303          Writing Across Media
# 11817  2023  Spring  2023-sp    WRIT     303          Writing Across Media
# 11818  2023  Spring  2023-sp    WRIT     303          Writing Across Media
# 11819  2023  Spring  2023-sp    WRIT     303          Writing Across Media
# 11820  2023  Spring  2023-sp    ZULU     202            Elementary Zulu II
#
# ...

# %%
df.sample(5)
# Out:
#       Year    Term YearTerm Subject  Number  \
# 5478  2023  Spring  2023-sp     GRK     199
# 4597  2023  Spring  2023-sp    EPOL     471
# 5984  2023  Spring  2023-sp      IE     525
# 7443  2023  Spring  2023-sp    MATH     257
# 3274  2023  Spring  2023-sp      CS     445
#
#                                                    Name  \
# 5478                         Undergraduate Open Seminar
# 4597  Business Principles for Human Resource Develop...
# 5984  Stochastic Calculus &amp; Numerical Models in ...
# 7443     Linear Algebra with Computational Applications
# 3274                          Computational Photography
#
#                                             Description   Credit Hours  \
# 5478                                   May be repeated.  1 TO 5 hours.
# 4597  Study of essential business understandings, kn...  3 OR 4 hours.
# 5984  Basic theory of stochastic differential equati...       2 hours.
# ...

# %%
df.head(5)
# Out:
#    Year    Term YearTerm Subject  Number                          Name  \
# 0  2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 1  2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 2  2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 3  2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 4  2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
#
#                                          Description Credit Hours  \
# 0  Interdisciplinary introduction to the basic co...     3 hours.
# 1  Interdisciplinary introduction to the basic co...     3 hours.
# 2  Interdisciplinary introduction to the basic co...     3 hours.
# 3  Interdisciplinary introduction to the basic co...     3 hours.
# 4  Interdisciplinary introduction to the basic co...     3 hours.
#
#   Section Info                                  Degree Attributes  ...  \
# ...

# %%
df.tail(5)
# Out:
#        Year    Term YearTerm Subject  Number                  Name  \
# 11816  2023  Spring  2023-sp    WRIT     303  Writing Across Media
# 11817  2023  Spring  2023-sp    WRIT     303  Writing Across Media
# 11818  2023  Spring  2023-sp    WRIT     303  Writing Across Media
# 11819  2023  Spring  2023-sp    WRIT     303  Writing Across Media
# 11820  2023  Spring  2023-sp    ZULU     202    Elementary Zulu II
#
#                                              Description Credit Hours  \
# 11816                    Same as INFO 303. See INFO 303.     3 hours.
# 11817                    Same as INFO 303. See INFO 303.     3 hours.
# 11818                    Same as INFO 303. See INFO 303.     3 hours.
# 11819                    Same as INFO 303. See INFO 303.     3 hours.
# 11820  Continuation of ZULU 201 with introduction of ...     5 hours.
#
#                                             Section Info  \
# 11816                    Same as INFO 303. See INFO 303.
# ...

# %%
df.describe()
# Out:
#           Year        Number           CRN
# count  11821.0  11821.000000  11821.000000
# mean    2023.0    361.691904  54601.367905
# std        0.0    174.261191  17260.841718
# min     2023.0     90.000000  10001.000000
# 25%     2023.0    210.000000  38177.000000
# 50%     2023.0    391.000000  58726.000000
# 75%     2023.0    498.000000  70769.000000
# max     2023.0    799.000000  75398.000000

# %%
#Dataframe conditionals
df[df.Subject == "MATH"]
# Out:
#       Year    Term YearTerm Subject  Number                            Name  \
# 7248  2023  Spring  2023-sp    MATH     103            Theory of Arithmetic
# 7249  2023  Spring  2023-sp    MATH     103            Theory of Arithmetic
# 7250  2023  Spring  2023-sp    MATH     103            Theory of Arithmetic
# 7251  2023  Spring  2023-sp    MATH     103            Theory of Arithmetic
# 7252  2023  Spring  2023-sp    MATH     112                         Algebra
# ...    ...     ...      ...     ...     ...                             ...
# 7642  2023  Spring  2023-sp    MATH     595  Advanced Topics in Mathematics
# 7643  2023  Spring  2023-sp    MATH     595  Advanced Topics in Mathematics
# 7644  2023  Spring  2023-sp    MATH     595  Advanced Topics in Mathematics
# 7645  2023  Spring  2023-sp    MATH     597                  Reading Course
# 7646  2023  Spring  2023-sp    MATH     599                 Thesis Research
#
# ...

# %%
df[df["Credit Hours"] == "4 hours."]
# Out:
#        Year    Term YearTerm Subject  Number  \
# 26     2023  Spring  2023-sp     AAS     310
# 27     2023  Spring  2023-sp     AAS     310
# 28     2023  Spring  2023-sp     AAS     310
# 29     2023  Spring  2023-sp     AAS     310
# 38     2023  Spring  2023-sp     AAS     539
# ...     ...     ...      ...     ...     ...
# 11716  2023  Spring  2023-sp      UP     576
# 11737  2023  Spring  2023-sp     VCM     561
# 11791  2023  Spring  2023-sp      VM     606
# 11811  2023  Spring  2023-sp    WGGP     581
# 11813  2023  Spring  2023-sp    WLOF     404
#
#                                    Name  \
# 26          Race and Cultural Diversity
# 27          Race and Cultural Diversity
# 28          Race and Cultural Diversity
# 29          Race and Cultural Diversity
# 38           Youth, Culture and Society
# ...                                 ...
# 11716         Sustainable Urban Systems
# 11737  Biosecurity in Livestock Systems
# 11791              Clinical Practice II
# ...

# %%
df[(df["Number"] >= 100) & (df["Number"] <= 199)]
# Out:
#        Year    Term YearTerm Subject  Number  \
# 0      2023  Spring  2023-sp     AAS     100
# 1      2023  Spring  2023-sp     AAS     100
# 2      2023  Spring  2023-sp     AAS     100
# 3      2023  Spring  2023-sp     AAS     100
# 4      2023  Spring  2023-sp     AAS     100
# ...     ...     ...      ...     ...     ...
# 11671  2023  Spring  2023-sp      UP     116
# 11672  2023  Spring  2023-sp      UP     116
# 11673  2023  Spring  2023-sp      UP     136
# 11674  2023  Spring  2023-sp      UP     160
# 11675  2023  Spring  2023-sp      UP     199
#
#                                    Name  \
# 0          Intro Asian American Studies
# 1          Intro Asian American Studies
# 2          Intro Asian American Studies
# 3          Intro Asian American Studies
# 4          Intro Asian American Studies
# ...                                 ...
# 11671               Urban Informatics I
# 11672               Urban Informatics I
# 11673              Urban Sustainability
# ...
